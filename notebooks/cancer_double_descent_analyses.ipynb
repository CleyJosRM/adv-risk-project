# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
import numpy as np
from src.data_utils import load_and_prep_cancer_arff
from src.simulation import run_simulation_in_data
from src.visualization import plot_comparison

# %%
X, y = load_and_prep_cancer_arff('../data/Breast.arff')

eps_value = 0.5
results = run_simulation_in_data(X, y, n_experiments=10, epsilon=eps_value, mode='importance')

plot_comparison(results, epsilon_label=str(eps_value))
